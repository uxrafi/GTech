# %% [markdown]
# # DVA HW4 Q1
# ## Pagerank Algorithm
#
# Do not distribute or publish this code
# Do not change the `#export` statements or add and other code or comments above them. They are needed for grading.

# %%
#export
'''
*** Imports ***
    DO NOT EDIT or add anything to this section
'''
import numpy as np
import time
import argparse
import sys

# %% [markdown]
# ### Update your GT username and Id

# %%
#export
def author():                                                                                             
        return "urafi3"      # replace gburdell3 with your Georgia Tech username.                                                                                             
                                                                                              
def gtid():                                                                                               
    return 904074839            # replace with your GT ID number (https://registrar.gatech.edu/info/gtid-lookup)

# %%
'''
*** Utility function ***
    DO NOT EDIT
'''
def dump_results(command, iterations, result):
    print("Sorting...", file=sys.stderr)
    sorted_result = sorted(enumerate(result), key=lambda x: x[1], reverse=True)
    output_result = "node_id\tpr_value\n"
    for node_id, pr_value in sorted_result[:10]:
        output_result += "{0}\t{1}\n".format(node_id, pr_value)
    print(output_result)

    with open(command+'_iter'+str(iterations)+".txt","w") as output_file:
        output_file.write(output_result)

# %% [markdown]
# ### PageRank Class
# Please add your code as indicated below
# You do not need to add code outside of the indicated areas

# %%
#export
class PageRank:
    def __init__(self, edge_file):

        self.node_degree = {}
        self.max_node_id = 0
        self.edge_file = edge_file

    def read_edge_file(self, edge_file):
        with open(edge_file) as f:
            for line in f:
                val = line.split('\t')
                yield int(val[0]), int(val[1])

    """
    Step1: Calculate the out-degree of each node and maximum node_id of the graph.
    Store the out-degree in class variable "node_degree" and maximum node id to "max_node_id".
    """
    def calculate_node_degree(self):
        for source,target in self.read_edge_file(self.edge_file):

            ### STEP 1
            ### Implement your code here
            #############################################
            # Count out-degree for the source node
            if source in self.node_degree:
                self.node_degree[source] += 1
            else:
                self.node_degree[source] = 1
            
            # Update maximum node ID to include both source and target
            self.max_node_id = max(self.max_node_id, source, target)

        # Print summary for verification (can remove if needed for Gradescope)
        #############################################

        print("Max node id: {}".format(self.max_node_id))
        print("Total source number: {}".format(len(self.node_degree)))

    def get_max_node_id(self):
        return self.max_node_id

    def run_pagerank(self, node_weights, damping_factor=0.85, iterations=10):
        pr_values = [1.0 / (self.max_node_id + 1)] * (self.max_node_id + 1)
        start_time = time.time()

        for it in range(iterations):
            new_pr_values = [0.0] * (self.max_node_id + 1)
            
            # Distribute PageRank from sources to targets
            for source, target in self.read_edge_file(self.edge_file):
                if self.node_degree.get(source, 0) > 0:
                    new_pr_values[target] += damping_factor * pr_values[source] / self.node_degree[source]

            # Add random jump contribution
            for node_id in range(self.max_node_id + 1):
                new_pr_values[node_id] += (1 - damping_factor) * node_weights[node_id]

            # Update pr_values for next iteration
            pr_values = new_pr_values

            print("Completed {0}/{1} iterations. {2} seconds elapsed.".format(it + 1, iterations, time.time() - start_time))

        return pr_values

# %% [markdown]
# ### Simplified Pagerank

# %%
# Options
file = 'network.tsv'                # Input file of the edge list - DO NOT EDIT
command = 'simplified_pagerank'     # Command to run - DO NOT EDIT
damping_factor = 0.85               # Damping factor - submit results for damping_factor = 0.85
iterations = [10,25]                # Number of iterations - sumbit results for iterations = [10,25] 

# Run Simplified PageRank
# DO NOT EDIT
for i in iterations:
    pr = PageRank(file)
    pr.calculate_node_degree()
    max_node_id = pr.get_max_node_id()
    node_weights = np.ones(max_node_id + 1) / (max_node_id + 1)
    result = pr.run_pagerank(node_weights=node_weights, iterations=i, damping_factor=damping_factor)
    dump_results(command, i, result )
# Out:
# Max node id: 1157826
# Total source number: 374785
# Completed 1/10 iterations. 8.588482141494751 seconds elapsed.
# Completed 2/10 iterations. 20.31624746322632 seconds elapsed.
# Completed 3/10 iterations. 30.76220393180847 seconds elapsed.
# Completed 4/10 iterations. 42.42222762107849 seconds elapsed.
# Completed 5/10 iterations. 52.43230962753296 seconds elapsed.
# Completed 6/10 iterations. 63.162325620651245 seconds elapsed.
# Completed 7/10 iterations. 74.49865484237671 seconds elapsed.
# Completed 8/10 iterations. 85.67862749099731 seconds elapsed.
# Completed 9/10 iterations. 97.07199549674988 seconds elapsed.
# Completed 10/10 iterations. 106.98032736778259 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.0001724404640087135
# 482708	9.409193541687527e-05
# 1034017	5.480094973243455e-05
# 663559	4.87472647440821e-05
# 357530	4.5615623513891224e-05
# 1120567	4.4870100282189497e-05
# 663605	4.3482910860663805e-05
# 663682	3.65943675279321e-05
# 1108860	3.5276046684522986e-05
# 664788	3.503597066140542e-05
#
# Max node id: 1157826
# Total source number: 374785
# Completed 1/25 iterations. 8.899129390716553 seconds elapsed.
# Completed 2/25 iterations. 18.167084455490112 seconds elapsed.
# Completed 3/25 iterations. 28.222856521606445 seconds elapsed.
# Completed 4/25 iterations. 38.56035304069519 seconds elapsed.
# Completed 5/25 iterations. 50.278910875320435 seconds elapsed.
# Completed 6/25 iterations. 61.1089653968811 seconds elapsed.
# Completed 7/25 iterations. 72.54894948005676 seconds elapsed.
# Completed 8/25 iterations. 84.7588119506836 seconds elapsed.
# Completed 9/25 iterations. 96.58393883705139 seconds elapsed.
# Completed 10/25 iterations. 107.69888544082642 seconds elapsed.
# Completed 11/25 iterations. 118.27190351486206 seconds elapsed.
# Completed 12/25 iterations. 128.5006799697876 seconds elapsed.
# Completed 13/25 iterations. 138.32308673858643 seconds elapsed.
# Completed 14/25 iterations. 147.62737464904785 seconds elapsed.
# Completed 15/25 iterations. 157.78531074523926 seconds elapsed.
# Completed 16/25 iterations. 167.35924339294434 seconds elapsed.
# Completed 17/25 iterations. 176.869309425354 seconds elapsed.
# Completed 18/25 iterations. 187.97907209396362 seconds elapsed.
# Completed 19/25 iterations. 198.81175422668457 seconds elapsed.
# Completed 20/25 iterations. 211.17438864707947 seconds elapsed.
# Completed 21/25 iterations. 222.84888315200806 seconds elapsed.
# Completed 22/25 iterations. 231.76894235610962 seconds elapsed.
# Completed 23/25 iterations. 240.36925840377808 seconds elapsed.
# Completed 24/25 iterations. 249.788991689682 seconds elapsed.
# Completed 25/25 iterations. 259.24603629112244 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.000172438581121727
# 482708	9.409158864049368e-05
# 1034017	5.478941005079604e-05
# 663559	4.874698942960063e-05
# 357530	4.561544279769612e-05
# 1120567	4.4847128373773044e-05
# 663605	4.348263426865654e-05
# 663682	3.659435702898396e-05
# 1108860	3.5251801674277104e-05
# 664788	3.5035704161325006e-05

# %% [markdown]
# ### Personalized Pagerank

# %%
# Options
file = 'network.tsv'                # Input file of the edge list - DO NOT EDIT
command = 'personalized_pagerank'   # Command to run - DO NOT EDIT
damping_factor = 0.85               # Damping factor - submit results for damping_factor = 0.85
iterations = [10,25]                # Number of iterations - sumbit results for iterations = [10,25] 

# Run Personalized PageRank
# DO NOT EDIT
for i in iterations:
    pr = PageRank(file)
    pr.calculate_node_degree()
    max_node_id = pr.get_max_node_id()
    np.random.seed(gtid())
    node_weights = np.random.rand(max_node_id + 1)
    node_weights = node_weights/node_weights.sum()
    result = pr.run_pagerank(node_weights=node_weights, iterations=i, damping_factor=damping_factor)
    dump_results(command, i, result)
# Out:
# Max node id: 1157826
# Total source number: 374785
# Completed 1/10 iterations. 8.847785472869873 seconds elapsed.
# Completed 2/10 iterations. 19.03779435157776 seconds elapsed.
# Completed 3/10 iterations. 28.27874493598938 seconds elapsed.
# Completed 4/10 iterations. 34.367934226989746 seconds elapsed.
# Completed 5/10 iterations. 43.45165014266968 seconds elapsed.
# Completed 6/10 iterations. 54.587960958480835 seconds elapsed.
# Completed 7/10 iterations. 64.16389918327332 seconds elapsed.
# Completed 8/10 iterations. 73.47973155975342 seconds elapsed.
# Completed 9/10 iterations. 84.46990656852722 seconds elapsed.
# Completed 10/10 iterations. 92.74854278564453 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.00016973871892723787
# 482708	9.573560213761846e-05
# 1034017	5.524056282596069e-05
# 663559	4.895914541412147e-05
# 357530	4.5716822226921606e-05
# 1120567	4.542955631428015e-05
# 663605	4.2835939152243785e-05
# 663682	3.7051985690741995e-05
# 1108860	3.4994643216743645e-05
# 664788	3.4332121105128505e-05
#
# Max node id: 1157826
# Total source number: 374785
# Completed 1/25 iterations. 9.101577043533325 seconds elapsed.
# Completed 2/25 iterations. 19.801403760910034 seconds elapsed.
# Completed 3/25 iterations. 30.252148151397705 seconds elapsed.
# Completed 4/25 iterations. 40.68764042854309 seconds elapsed.
# Completed 5/25 iterations. 51.871654748916626 seconds elapsed.
# Completed 6/25 iterations. 61.985289335250854 seconds elapsed.
# Completed 7/25 iterations. 73.49438881874084 seconds elapsed.
# Completed 8/25 iterations. 84.09775733947754 seconds elapsed.
# Completed 9/25 iterations. 94.36276149749756 seconds elapsed.
# Completed 10/25 iterations. 104.86816048622131 seconds elapsed.
# Completed 11/25 iterations. 115.81842827796936 seconds elapsed.
# Completed 12/25 iterations. 127.12912917137146 seconds elapsed.
# Completed 13/25 iterations. 137.554936170578 seconds elapsed.
# Completed 14/25 iterations. 148.36781811714172 seconds elapsed.
# Completed 15/25 iterations. 160.67778611183167 seconds elapsed.
# Completed 16/25 iterations. 171.9931516647339 seconds elapsed.
# Completed 17/25 iterations. 183.06813311576843 seconds elapsed.
# Completed 18/25 iterations. 194.22790813446045 seconds elapsed.
# Completed 19/25 iterations. 204.95573353767395 seconds elapsed.
# Completed 20/25 iterations. 216.01762175559998 seconds elapsed.
# Completed 21/25 iterations. 226.61773538589478 seconds elapsed.
# Completed 22/25 iterations. 237.58329439163208 seconds elapsed.
# Completed 23/25 iterations. 248.86817264556885 seconds elapsed.
# Completed 24/25 iterations. 259.2192931175232 seconds elapsed.
# Completed 25/25 iterations. 270.7576656341553 seconds elapsed.
# Sorting...
# node_id	pr_value
# 663930	0.00016973683978589464
# 482708	9.573525636292712e-05
# 1034017	5.522903589191777e-05
# 663559	4.8958870466989546e-05
# 357530	4.5716641731818226e-05
# 1120567	4.5406553539802535e-05
# 663605	4.283566269182588e-05
# 663682	3.705197519436297e-05
# 1108860	3.4970471521036855e-05
# 664788	3.433185514948872e-05

# %% [markdown]
# ### Submitting your results to gradescope
# Submit the following on Gradescope
# * Q1.ipynb
# * simplified_pagerank_iter10.txt
# * simplified_pagerank_iter25.txt
# * personalized_pagerank_iter10.txt
# * personalized_pagerank_iter25.txt
